# %%
import requests
from bs4 import BeautifulSoup
import json
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

from selenium.common.exceptions import TimeoutException, NoSuchElementException
def get_exhibitor_list(url):
    exhibitor_info=[]
    try:
        driver = webdriver.Chrome(ChromeDriverManager().install())
        driver.get(url)
        html=driver.page_source
        print(html)
        
#         for page in range(page_nums):
#             exhibitor_info_list=[]
#             html=driver.page_source
#             soup=BeautifulSoup(html,'html.parser')
#             tr_list=soup.find_all('tr',class_='odd')+soup.find_all('tr',class_='even')
#             for tr in tr_list:
#                 exhibitor_info_dict={}
#                 exhibitor_info_dict['公司名称']=tr.find('div',class_='ExhList_CompanyName').text
#                 exhibitor_info_dict['展位']=tr.find('ul',class_='ExhList_BoothNo').text
#                 exhibitor_info_dict['国家']=tr.find_all('td')[3].text
#                 exhibitor_info_list.append(exhibitor_info_dict)
#             exhibitor_info=exhibitor_info+exhibitor_info_list
#             driver.find_element_by_link_text(u"下页").click()
#             time.sleep(2)
        print('Time Out')
    finally:
        driver.close()
        return exhibitor_info
        
url = 'https://wuhan.anjuke.com/'
exhibitor_result=get_exhibitor_list(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [/Users/yanshuo/.wdm/drivers/chromedriver/mac64/90.0.4430.24/chromedriver] found in cache
# <html><head>
#
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# <meta name="format-detection" content="telephone=no">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="location" content="province=湖北;city=武汉;coord=114.31965,30.576855">
# <meta name="mobile-agent" content="format=html5; url=https://m.anjuke.com/wh/">
# <link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.anjuke.com/wh/">
# <title>武汉房产网，武汉二手房，租房，新房，房产信息网–武汉58安居客</title><meta name="keywords" content="武汉房产网，武汉租房，武汉二手房">
# <meta name="description" content="安居客武汉房产网为用户提供找房信息。包括武汉二手房、新房、租房、商铺、写字楼、海外地产、问答等，挑好房就上安居客武汉房地产信息网。">
# <meta name="apple-itunes-app" content="app-id=527806786">
# <link rel="canonical" href="https://wuhan.anjuke.com/">
#
# <meta name="baidu-site-verification" content="e8abd676df9f995bc969ac138b1c0f4d">
# <meta name="sogou_site_verification" content="7rtgKfBjbl">
# <meta name="360-site-verification" content="f7b8b308108b2c1c2de2825948822256">
# <meta name="google-site-verification" content="drkSj5A3WGSgkMXwzh6UfezwLEMsEXoQlMHL25oE1kA">
# <meta baidu-gxt-verify-token="9e7961d9a5d01603e5c2ae9bccffb9c2">
# <meta name="shenma-site-verification" content="da9c53da88979ec98afae25b1ca3e43b">
# <link rel="dns-prefetch" href="//lego-click.anjuke.com">
# <!--start-->
# <link rel="stylesheet" rev="stylesheet" href="https://include.anjukestatic.com/anjuke-user/res/20210602.9618.0/b/Ershou_Web_Home_Home.css" type="text/css">
# <!--end-->
# <script src="https://zz.bdstatic.com/linksubmit/push.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script type="text/javascript">var PAGESTART = +new Date(); var PHPVERSION = '20210602.9618.0';</script>
#
# <script type="text/javascript" src="//include.anjukestatic.com/usjs/base/logger/dom.dom/dom.query/ajax/event/ui.panel/ui.autocomplete/ui.exposure/cookie/site/utils.base/17b603cd6f9712576e5178b40eecc1a4.js"></script><link type="text/css" rel="stylesheet" href="//include.anjukestatic.com/uscss/ui.login/17b603cd6f9712576e5178b40eecc1a4.css">
# <!-- <script type="text/javascript" src="//include.anjukestatic.com/ujs/chat.opener/17b603cd6f9712576e5178b40eecc1a4.js" crossorigin></script> -->
# <script type="text/javascript">J.site.init()</script>
#
#
# <!-- -->
# <link rel="shortcut icon" href="https://pages.anjukestatic.com/usersite/site/img/global/1/favicon.ico">
# <link rel="icon" href="https://pages.anjukestatic.com/usersite/site/img/global/1/favicon.ico" type="image/ico"><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=926&amp;first=1&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=932&amp;first=1&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=1000&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=930&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=929&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=1001&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=927&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=928&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=935&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=1002&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=3006&amp;o=1&amp;f=home_jjr_tgy"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=931&amp;o=1"></script><script async="" src="https://ifx.anjuke.com/s?c=22&amp;p=933&amp;o=1"></script>
#
# <link type="text/css" rel="stylesheet" href="//include.anjukestatic.com/uscss//17b603cd6f9712576e5178b40eecc1a4.css"><script type="text/javascript" src="//include.anjukestatic.com/usjs/ui.loopSlide/17b603cd6f9712576e5178b40eecc1a4.js" async="" charset="utf-8"></script><link type="text/css" rel="stylesheet" href="//include.anjukestatic.com/uscss/ui.autocomplete_ajk/17b603cd6f9712576e5178b40eecc1a4.css"><script type="text/javascript" src="//include.anjukestatic.com/usjs/ui.autocompleteSite/17b603cd6f9712576e5178b40eecc1a4.js" async="" charset="utf-8"></script><script type="text/javascript" src="//pages.anjukestatic.com/prism/performance.js?v=1501241237" async="" charset="utf-8"></script><div><iframe style="display:none" id="sojtracker0" name="sojtracker0" height="300" width="500"></iframe></div><form action="https://s.anjuke.com/stb?__site=anjuke&amp;" method="post" target="sojtracker0"><input type="hidden" name="p" value="Ershou_Web_Home_HomePage"><input type="hidden" name="h" value="https://wuhan.anjuke.com/"><input type="hidden" name="r" value=""><input type="hidden" name="site" value="anjuke"><input type="hidden" name="guid" value="4AF626AF-F7EC-6490-976E-4791E70404D7"><input type="hidden" name="ssid" value="DD4FE9CD-A75E-6DC4-DD03-EC4C59E7802A"><input type="hidden" name="uid" value="0"><input type="hidden" name="t" value="1622688641097"><input type="hidden" name="ctid" value="22"><input type="hidden" name="luid" value=""><input type="hidden" name="m" value=""><input type="hidden" name="sc" value="{&quot;w&quot;:&quot;1200&quot;,&quot;h&quot;:&quot;708&quot;,&quot;r&quot;:&quot;1&quot;}"><input type="hidden" name="pn" value="Ershou_Web_Home_HomePage"><input type="hidden" name="cp" value="{&quot;exposure&quot;:{&quot;Anjuke_home_Property_viewed_SearchBar&quot;:[1]}}"><input type="hidden" name="ep" value="{&quot;tid&quot;:{},&quot;exposure&quot;:{}}"><input type="hidden" name="plat" value="1"><input type="hidden" name="type" value="3"></form><div><iframe style="display:none" id="sojtracker1" name="sojtracker1" height="300" width="500"></iframe></div><form action="https://s.anjuke.com/stb?__site=anjuke&amp;" method="post" target="sojtracker1"><input type="hidden" name="p" value="Ershou_Web_Home_HomePage"><input type="hidden" name="h" value="https://wuhan.anjuke.com/"><input type="hidden" name="r" value=""><input type="hidden" name="site" value="anjuke"><input type="hidden" name="guid" value="4AF626AF-F7EC-6490-976E-4791E70404D7"><input type="hidden" name="ssid" value="DD4FE9CD-A75E-6DC4-DD03-EC4C59E7802A"><input type="hidden" name="uid" value="0"><input type="hidden" name="t" value="1622688645083"><input type="hidden" name="ctid" value="22"><input type="hidden" name="luid" value=""><input type="hidden" name="m" value=""><input type="hidden" name="sc" value="{&quot;w&quot;:&quot;1200&quot;,&quot;h&quot;:&quot;708&quot;,&quot;r&quot;:&quot;1&quot;}"><input type="hidden" name="pn" value="Ershou_Web_Home_HomePage"><input type="hidden" name="cp" value="{&quot;exposure&quot;:{&quot;Anjuke_home_Property_viewed_newhouse&quot;:[1]}}"><input type="hidden" name="ep" value="{&quot;tid&quot;:{},&quot;exposure&quot;:{}}"><input type="hidden" name="plat" value="1"><input type="hidden" name="type" value="3"></form><div><iframe style="display:none" id="sojtracker2" name="sojtracker2" height="300" width="500"></iframe></div><form action="https://s.anjuke.com/stb?__site=anjuke-npv&amp;" method="post" target="sojtracker2"><input type="hidden" name="p" value="Ershou_Web_Home_HomePage_tracklog"><input type="hidden" name="h" value="https://wuhan.anjuke.com/"><input type="hidden" name="r" value=""><input type="hidden" name="site" value="anjuke-npv"><input type="hidden" name="guid" value="4AF626AF-F7EC-6490-976E-4791E70404D7"><input type="hidden" name="ssid" value="DD4FE9CD-A75E-6DC4-DD03-EC4C59E7802A"><input type="hidden" name="uid" value="0"><input type="hidden" name="t" value="1622688645591"><input type="hidden" name="ctid" value="22"><input type="h ...
# <body data-page="Ershou_Web_Home_HomePage">
#
#
# <div style="position: absolute; z-index: 10100;"><div class="autocomplete_ajk" id="Autocomplete_8dca48" style="display:none; width:389px"></div></div><div id="container">
#     <div id="header">
#             <!-- 头部广告位 -->
#
#     <div class="top-poster">
#         <div id="IFX_p926" class="ifx-wrap " style="display:none;position:relative;"></div>
#
#
# <div style="display: none">
#
#     </div>
#     </div>
#         <div class="top-poster">
#         <div id="IFX_p932" class="ifx-wrap " style="display:none;position:relative;"></div>
#
#
# <div style="display: none">
#
#     </div>
#     </div>
#
# <div class="glbLogo">
#     <div class="glbL clearfix">
#         <a class="logo aaaa" href="https://wuhan.anjuke.com" title="安居客武汉房产网"></a>
#             <div class="cur_citynew">
#         <div id="switch_apf_id_8" class="select_icon"><span class="city">武汉</span><span class="city_icon"></span></div>
#         <div id="city-panel" class="city_panel" style="display:none;">
#                         <dl>
#                 <dt>华北东北</dt>
#                 <dd>
#                                         <a href="https://beijing.anjuke.com/" title="北京房产网">北京</a>
#                                         <a href="https://tianjin.anjuke.com/" title="天津房产网">天津</a>
#                                         <a href="https://dalian.anjuke.com/" title="大连房产网">大连</a>
#                                                     <a href="https://wh.zu.anjuke.com/" hidefocus="true" _soj="navigation" class="">
#                                 区域找房                            </a>
#                                                 <a href="https://wh.zu.anjuke.com/ditie/" hidefocus="true" _soj="navigation" class="">
#                                 地铁找房                            </a>
#                                                 <a href="https://wh.zu.anjuke.com/ditu/" hidefocus="true" _soj="navigation" target="_blank" class="underline">
#                                 地图找房                            </a>
#                                                 <a href="https://wuhan.anjuke.com/community/" hidefocus="true" _soj="navigation" class="">
#                                 小区                            </a>
#                                                 <a href="https://wh.zu.anjuke.com/duanzu/" hidefocus="true" _soj="navigation" class="">
#                                 民宿短租                            </a>
#                                                                                                                                 <a href="http://wh.58.com/pinpaigongyu/" target="_blank" rel="nofollow" hidefocus="true" _soj="ajkp_home_zf_daohang_ppgy_wwl&amp;logofrom=anjuke" id="ppgy-58nav">品牌公寓</a>
#                                                                                </div>
#                                         </li>
#             <li class="li_single li_itemsnew li_unselected">
#                                     <a class="a_navnew" hidefocus="true" href="https://wh.sydc.anjuke.com/xzl-zu/">商铺写字楼</a>
#                     <div class="sec_divnew" style="display: none;">
#                         <div class="arrow_upnew" style="left: 53px;"></div>
#                         <div class="sec_navlist">
#                                                             <div class="third_navlist">
#                                     <!-- <div class="third_nav_title">商铺</div> -->
#                                                                             <a href="https://wh.sydc.anjuke.com/sp-zu/">商铺</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/sp-zu/">商铺出租</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/sp-shou/">商铺出售</a>
#                                                                             <a href="https://wh.fang.anjuke.com/sp/all/w4/">商铺新盘</a>
#                                                                     </div>
#                                                             <div class="third_navlist">
#                                     <!-- <div class="third_nav_title">写字楼</div> -->
#                                                                             <a href="https://wh.sydc.anjuke.com/xzl-zu/">写字楼</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/xzl-zu/">写字楼出租</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/xzl-shou/">写字楼出售</a>
#                                                                             <a href="https://wh.fang.anjuke.com/xzl/all/w5/">写字楼新盘</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/shangban/loupan/?from=spxzl_index_float_bglp">办公楼盘</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/shang-lhbg/?from=spxzl_index_float_lhbg">联合办公</a>
#                                                                     </div>
#                                                             <div class="third_navlist">
#                                     <!-- <div class="third_nav_title">厂房</div> -->
#                                                                             <a href="https://wh.sydc.anjuke.com/cf-zu/">厂房</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/cf-zu/">厂房出租</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/cf-shou/">厂房出售</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/cf-zhuan/">厂房转让</a>
#                                                                     </div>
#                                                             <div class="third_navlist">
#                                     <!-- <div class="third_nav_title">仓库</div> -->
#                                                                             <a href="https://wh.sydc.anjuke.com/ck-zu/">仓库</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/ck-zu/">仓库出租</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/ck-shou/">仓库出售</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/ck-zhuan/">仓库转让</a>
#                                                                     </div>
#                                                             <div class="third_navlist">
#                                     <!-- <div class="third_nav_title">土地</div> -->
#                                                                             <a href="https://wh.sydc.anjuke.com/td-zu/">土地</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/td-zu/">土地出租</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/td-shou/">土地出售</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/td-zhuan/">土地转让</a>
#                                                                     </div>
#                                                             <div class="third_navlist">
#                                     <!-- <div class="third_nav_title">车位</div> -->
#                                                                             <a href="https://wh.sydc.anjuke.com/cw-zu/">车位</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/cw-zu/">车位出租</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/cw-shou/">车位出售</a>
#                                                                             <a href="https://wh.sydc.anjuke.com/cw-zhuan/">车位转让</a>
#                                                                     </div>
#                                                     </div>
#                     </div>
#                             </li>
#             <li class="li_single  li_unselected">
#                                 <a class="a_navnew" hidefocus="true" href="https://haiwai.anjuke.com" _soj="navigation">海外地产</a>
#                                                 </li>
#             <li class="li_single  li_unselected">
#                                 <a class="a_navnew" hidefocus="true" href="https://jiazhuang.anjuke.com/wuhan/gongsi/" _soj="navigation">装修</a>
#                                                 </li>
#             <li class="li_single  li_unselected">
#                                 <a class="a_navnew" hidefocus="true" href="http://wh.news.anjuke.com/" _soj="navigation">楼 讯</a>
#                                                 </li>
#             <li class="li_single  li_unselected">
#                                 <a class="a_navnew" hidefocus="true" href="https://ai.anjuke.com/?action=hydc" _soj="navigation">房产研究院</a>
#                                                 </li>
#             <li class="li_single  li_unselected">
#                                     <a class="a_navnew" hidefocus="true" href="https://wuhan.anjuke.com/market/">房 价</a>
#                                                 </li>
#             <li class="li_single  li_unselected">
#                                 <a class="a_navnew" hidefocus="true" href="https://wuhan.anjuke.com/ask/" _soj="navigation">问 答</a>
#                                                 </li>
#     </ul>
#
# <!-- 用户信息 TabBarNew pmt-38357 -->
# <div class="R_user" url="https://user.anjuke.com/" style="height: 48px;float:right;">
#     <div class="login_info">
#         <div class="l" id="login_l" style="margin-right:10px">
#             <div class="m">
#                 <a href="https://login.anjuke.com/login/form?history=aHR0cHM6Ly93dWhhbi5hbmp1a2UuY29tLw==" class="u_l" rel="nofollow">登录</a>
#                 <a href="https://login.anjuke.com/login/form?from=register" class="u_r" rel="nofollow">注册</a>
#             </div>
#         </div>
#
#         <div class="appContainer" style="width:108px">
#             <a class="downapp" style="width:98px" href="https://www.anjuke.com/mobile?from=navigation" rel="nofollow">
#                 <div class="apppic1"></div>
#                 <!-- <div class="apppic2"></div> -->
#                 <div class="apptext">下载APP</div>
#             </a>
#             <div class="h-qrcode">
#                 <img src="//pages.anjukestatic.com/usersite/site/img/global/2/pc-header.png" alt="" class="l-qrcode">
#                 <div class="r-t">
#                     <p class="r-t-t">下载安居客APP</p>
#                     <p class="r-t-d">随时随地查看新上房源</p>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
# <style type="text/css">
#     .login_info .usr {
#         width: 70px;
#         overflow: hidden;
#         display: inline-block;
#         text-overflow: ellipsis;
#         white-space: nowrap;
#     }
# </style>
#     </div>
# </div>
#     </div>
#     <div id="content">
#         <!-- 左侧内容展示 -->
# <div class="left-cont fl">
#     <!-- 首屏搜索框 -->
#     <div class="cont-wrap m-t-box">
#         <div class="box search-cont p-none clearfix">
#             <div class="left-tabs">
#                                     <a href="javascript:void(0);"><span class="tab h-tab cur-tab" data-type="1">买&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;房</span></a>
#                     <a href="javascript:void(0);"><span class="tab h-tab" data-type="8">卖&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;房</span></a>
#                     <a href="javascript:void(0);"><span class="tab" data-type="3">租&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;房</span></a>
#                     <a href="javascript:void(0);">
#                         <span class="tab" data-type="5">商铺写字楼</span>
#                     </a>
#                     <a href="javascript:void(0);">
#                         <span class="tab" data-type="11">厂房仓库</span>
#                     </a>
#                                             </div>
#
#             <div class="right-conts">
#                 <!-- 买房、租房、商业地产对应的搜索框 -->
#                 <form class="search search-form" method="GET" action="https://wuhan.anjuke.com/indexsearch/?from=SearchBar" target="_self" id="indexSearch" style="display:none;">
#                     <!-- <input type="hidden" value="home" name="from" id="search_soj" />-->
#                     <!--商业地产radios-->
#                     <div style="display: none;" id="contsydc" class="contsydc">
#                         <input hidefocus="true" type="radio" value="租写字楼" name="sydc_type" class="sydc-type fst-type" checked="true" data-text="租写字楼" data-type="5">&nbsp;租写字楼
#                         <input hidefocus="true" type="radio" value="买写字楼" name="sydc_type" class="sydc-type" data-text="买写字楼" data-type="4">&nbsp;买写字楼
#                         <input hidefocus="true" type="radio" value="买商铺" name="sydc_type" class="sydc-type" data-text="买商铺" data-type="6">&nbsp;买商铺
#                         <input hidefocus="true" type="radio" value="租商铺" name="sydc_type" class="sydc-type" data-text="租商铺" data-type="7">&nbsp;租商铺
#                         <input hidefocus="true" type="radio" value="生意转让" name="sydc_type" class="sydc-type" data-text="生意转让" data-type="9">&nbsp;生意转让
#                     </div>
#                     <!--厂房仓库tab、radios-->
#                     <div style="display: none;" id="navcfck" class="navcfck">
#                             <span class="tabcfck cur-tabcfck" data-type="12">厂房<i></i></span>
#                             <span class="tabcfck" data-type="13">仓库<i></i></span>
#                             <span class="tabcfck" data-type="14">土地<i></i></span>
#                             <span class="tabcfck" data-type="15">车位<i></i></span>
#                     </div>
#                     <div style="display: none;" id="radiocfck_12" class="radiocfck">
#                         <input hidefocus="true" type="radio" value="租厂房" name="cf-type" class="cfck-type cfck-type_12 fst-type checked" checked="true" data-text="租厂房" data-type="121">&nbsp;租厂房
#                         <input hidefocus="true" type="radio" value="售厂房" name="cf-type" class="cfck-type cfck-type_12" data-text="售厂房" data-type="122">&nbsp;售厂房
#                         <input hidefocus="true" type="radio" value="厂房转让" name="cf-type" class="cfck-type cfck-type_12" data-text="厂房转让" data-type="123">&nbsp;厂房转让
#                     </div>
#                     <div style="display: none;" id="radiocfck_13" class="radiocfck">
#                         <input hidefocus="true" type="radio" value="租仓库" name="ck-type" class="cfck-type cfck-type_13 fst-type checked" checked="true" data-text="租仓库" data-type="131">&nbsp;租仓库
#                         <input hidefocus="true" type="radio" value="售仓库" name="ck-type" class="cfck-type cfck-type_13" data-text="售仓库" data-type="132">&nbsp;售仓库
#                         <input hidefocus="true" type="radio" value="仓库转让" name="ck-type" class="cfck-type cfck-type_13" data-text="仓库转让" data-type="133">&nbsp;仓库转让
#                     </div>
#                     <div style="display: none;" id="radiocfck_14" class="radiocfck">
#                         <input hidefocus="true" type="radio" value="租土地" name="td-type" class="cfck-type cfck-type_14 fst-type checked" checked="true" data-text="租土地" data-type="141">&nbsp;租土地
#                         <input hidefocus="true" type="radio" value="售土地" name="td-type" class="cfck-type cfck-type_14" data-text="售土地" data-type="142">&nbsp;售土地
#                         <input hidefocus="true" type="radio" value="土地转让" name="td-type" class="cfck-type cfck-type_14" data-text="土地转让" data-type="143">&nbsp;土地转让
#                     </div>
#                     <div style="display: none;" id="radiocfck_15" class="radiocfck">
#                         <input hidefocus="true" type="radio" value="租车位" name="cw-type" class="cfck-type cfck-type_15 fst-type checked" checked="true" data-text="租车位" data-type="151">&nbsp;租车位
#                         <input hidefocus="true" type="radio" value="售车位" name="cw-type" class="cfck-type cfck-type_15" data-text="售车位" data-type="152">&nbsp;售车位
#                         <input hidefocus="true" type="radio" value="车位转让" name="cw-type" class="cfck-type cfck-type_15" data-text="车位转让" data-type="153">&nbsp;车位转让
#                     </div>
#                                         <input type="hidden" name="t" value="1" id="iptHidden" class="iptHidden">
#                     <!-- 买房搜新房 -->
#                     <div class="fd1 clearfix" id="searchIpt">
#                         <input type="text" name="kw" class="kw" id="glb_search0" maxlength="100" autocomplete="off" placeholder="请输入房源特征、地址、小区、楼盘名或…" value="">
#                         <i class="home-icon search-close" data-tracker="delete-kw" id="home_close" style="display: none;"></i><!--搜索关闭按钮-->
#
#                         <a href="javascript:void(0);" id="xfLink"><i class="btn-icon icon-xfzf"></i><input style="" type="button" id="otherBtn" class="btn-bg-xf btn otherBtn" value="新房"></a>
#                         <a href="javascript:void(0);"><i class="btn-icon" id="btnIcon"></i><input hidefocus="true" id="btnSubmit" type="submit" class="btn btnSubmit" value="二手房"></a>
#                     </div>
#                 </form>
#
#                 <!-- 买房搜二手房启用新搜索框 -->
#                 <form class="search search-form" method="GET" action="https://wuhan.anjuke.com/indexsearch/?from=SearchBar" target="_self" id="search-form">
#                     <input type="hidden" name="t" value="1" id="iptHidden" class="iptHidden">
#                     <div class="fd1 clearfix" id="searchIpt">
#                         <input type="text" name="kw" class="kw" id="search-esf" maxlength="100" autocomplete="off" placeholder="请输入小区名称、地址…" value="">
#                         <i class="home-icon search-close" data-tracker="delete-kw" id="search-close" style="display: none;"></i><!--搜索关闭按钮-->
#                         <a href="javascript:void(0);"><!--<i class="btn-icon" id="btnIcon"></i>--><input hidefocus="true" id="btnSubmit" type="submit" class="btn btnSubmit bg-icon" value="二手房"></a>
#                                                     <a href="javascript:void(0);" id="xfLink"><!--<i class="btn-icon icon-xfzf"></i>--><input style="" type="button" id="otherBtn" class="btn-bg-xf btn otherBtn bg-icon bg-icon-xf" value="新房"></a>
#                                             <div class="auto-wrap"></div></div>
#                 </form>
#
#                 <!--type 1:默认词, 2:搜索次数最多的小区词, 3:搜索过的词, 4:浏览过的房源所属小区词, 5:根据小区ID推荐的小区词, 6:用户输入后匹配到的词 -->
#                 <script type="text/template" id="search-tpl">
#                     <ul class="search-ul esf-search-ul">
#                         <%_.each(obj,function(item){%>
#                             <li link="<%= item.link %>">
#                                 <% if(item.type==2){%>
#                                     <em class="font_tag recom_tg">热门</em>
#                                 <% }else if(item.type==3){%>
#                                     <em class="font_tag sou_tg">搜过</em>
#                                 <% }else if(item.type==4){%>
#                                     <em class="font_tag kan_tg">看过</em>
#                                 <% }else if(item.type==5){%>
#                                     <em class="font_tag recom_tg">推荐</em>
#                                 <%}%>
#
#                                 <span <% if(item.type!=6 && item.type!=7 && item.type!=1){%>class="s_kw"<%}%> ><%= item.keyword %></span>
#                                 <label class="gray <%if(item.type==1){%>pz<%}%>"><%= item.description %></label>
#                                 <% if(item.type==6 && item.isa == 0 && item.address){%>
#                                     <label class="gray address">-&nbsp;<%= item.address %></label>
#                                 <%}%>
#                                 <% if(item.type == 7 && item.total) {%>
#                                 <label class="price">共<%= item.total %>个小区</label>
#                                 <% }else if(item.price){%><label class="price"><%= item.price %></label><%}%>
#
#                             </li>
#                         <%});%>
#                     </ul>
#                 </script>
#
#
#                 <!-- 买房 -->
#                 <div class="buy-house tab-contents" id="content_Rd1">
#
#                                     <!-- 买房(二手房、新房都有)style="display: none" -->
#                     <div class="clearfix">
#                                                 <!-- 二手房 -->
#                         <div class="details float_l">
#                                                         <a title="地图找房" alt="地图找房" class="map" href="https://wuhan.anjuke.com/map/sale/" _soj="SearchBar"><i class="home-icon"></i>地图找房</a>
#                                                         <p>二手房</p>
#                             <div class="areas">
#                                                                     <a title="洪山二手房" alt="洪山" class="hot-word" href="https://wuhan.anjuke.com/sale/hongshana/" target="_self" _soj="SearchBar">洪山</a>
#                                                                     <a title="武昌二手房" alt="武昌" class="hot-word" href="https://wuhan.anjuke.com/sale/wuchanga/" target="_self" _soj="SearchBar">武昌</a>
#                                                                     <a title="江岸二手房" alt="江岸" class="hot-word" href="https://wuhan.anjuke.com/sale/jiangan/" target="_self" _soj="SearchBar">江岸</a>
#                                                                     <a title="汉阳二手房" alt="汉阳" href="https://wuhan.anjuke.com/sale/hanyang/" target="_self" _soj="SearchBar">汉阳</a>
#                                                                     <a title="江夏二手房" alt="江夏" href="https://wuhan.anjuke.com/sale/jiangxiat/" target="_self" _soj="SearchBar">江夏</a>
#                                                                     <a title="江汉二手房" alt="江汉" href="https://wuhan.anjuke.com/sale/jianghana/" target="_self" _soj="SearchBar">江汉</a>
#                                                                     <a title="东西湖二手房" alt="东西湖" href="https://wuhan.anjuke.com/sale/dongxihu/" target="_self" _soj="SearchBar">东西湖</a>
#                                                                     <a title="硚口二手房" alt="硚口" href="https://wuhan.anjuke.com/sale/qiaokou/" target="_self" _soj="SearchBar">硚口</a>
#                                                                     <a title="黄陂二手房" alt="黄陂" href="https://wuhan.anjuke.com/sale/huangpiz/" target="_self" _soj="SearchBar">黄陂</a>
#                                                                     <a title="沌口开发区二手房" alt="沌口开发区" href="https://wuhan.anjuke.com/sale/zhuankouk/" target="_self" _soj="SearchBar">沌口开发区</a>
#                                                                     <a title="青山二手房" alt="青山" href="https://wuhan.anjuke.com/sale/qingshan/" target="_self" _soj="SearchBar">青山</a>
#                                                                     <a title="蔡甸二手房" alt="蔡甸" href="https://wuhan.anjuke.com/sale/caidianz/" target="_self" _soj="SearchBar">蔡甸</a>
#                                                                     <a title="黄陂" alt="黄陂" href="//wh.fang.anjuke.com/loupan/huangpi/" target="_self" _soj="SearchBar">黄陂</a>
#                                                                     <a title="武昌" alt="武昌" href="//wh.fang.anjuke.com/loupan/wuchang/" target="_self" _soj="SearchBar">武昌</a>
#                                                                     <a title="江夏" alt="江夏" href="//wh.fang.anjuke.com/loupan/jiangxia/" target="_self" _soj="SearchBar">江夏</a>
# ...
#                     var r = document.getElementById("IFX_p1000");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap1000").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=1000&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p930");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap930").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=930&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p929");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap929").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=929&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p1001");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap1001").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=1001&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p927");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap927").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=927&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p928");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap928").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=928&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p935");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap935").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=935&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p1002");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap1002").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=1002&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p3006");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap3006").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=3006&o=1&f=home_jjr_tgy';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p931");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap931").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=931&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
#         (function() {
#             var x = document.createElement('script');
#             x.async = true;
#             x.onload = function(){
#                 setTimeout(function(){
#                     var r = document.getElementById("IFX_p933");
#                     if(r.innerHTML.length > 10){
#                                                 $(r).show();
#                     }else{
#                         $("#contWrap933").hide();
#                     }
#                 },500);
#             }
#
#             x.src = 'https://ifx.anjuke.com/s?c=22&p=933&o=1';
#             var h = document.getElementsByTagName('head')[0];
#             if(h)h.insertBefore(x,h.lastChild);
#         })();
#
# jQuery(function(){
#     new ajk.pc.sideBar();
# })
# </script>
# <script type="text/javascript">
#     (function(){
#         function sendSoj(){
#
#
#             var fixReferer = '',
#                 curReferer = document.referrer,
#                 site = 'anjuke',
#                 CustomParams = '{}',
#                 ExposureParams = '{}',
#                 st =  new J.logger.Tracker();
#             st.setSite(site);
#             st.setPage("Ershou_Web_Home_HomePage");
#             st.setPageName("Ershou_Web_Home_HomePage");
#             st.setReferrer(curReferer ? curReferer : fixReferer);
#             st.setNGuid("aQQ_ajkguid");
#             st.setNUid("ajk_member_id");
#             st.setCustomParam(CustomParams);
#             st.setEp(ExposureParams);
#             try{
#                 st.track();
#             }catch(err){
#                 J.logger.log('sendSojError',err);
#             }
#         }
#         sendSoj();
#     }());
#     // 58 统计 不要cp、sc参数
#     (function(){
#
#         try{
#             var fixReferer = '',
#                 curReferer = document.referrer,
#                 site = 'anjuke',
#                 st = new SiteTracker();
#                 st.setSite(site);
#                 st.setPage("Ershou_Web_Home_HomePage");
#                 st.setPageName("Ershou_Web_Home_HomePage");
#                 st.setReferer(curReferer ? curReferer : fixReferer);
#                 st.buildParams();
#             var _trackUrl = st.getParams();
#                 delete _trackUrl.sc;
#                 delete _trackUrl.cp;
#             window._trackURL = JSON.stringify(_trackUrl);
#
#             function loadTrackjs(){
#                  var s = document.createElement('script');
#                  s.type = 'text/javascript';
#                  s.async = true;
#                  s.src = '//tracklog.58.com/referrer_anjuke_pc.js?_=' + Math.random();
#                  var b = document.body;
#                  s.onload = function () {
#                     st.setSite(site+'-npv');
#                     st.setPage("Ershou_Web_Home_HomePage"+"_tracklog");
#                     st.setPageName("Ershou_Web_Home_HomePage"+"_tracklog");
#                     st.track();
#                  }
#                  s.onerror = function () {
#                      st.setSite(site+'-npv');
#                      st.setPage("Ershou_Web_Home_HomePage"+"_tracklog_error");
#                      st.setPageName("Ershou_Web_Home_HomePage"+"_tracklog_error");
#                      st.track();
#                  }
#                  b.appendChild(s);
#             }
#             setTimeout(function(){loadTrackjs()},0);
#         }catch(e){
#         }
#     })();
# </script>
#
# <script>
#     ;(function(){
#         ajk.Logger.setSite('anjuke');
#         ajk.Logger.setPage('Ershou_Web_Home_HomePage');
#         ajk.Logger.setPageName('Ershou_Web_Home_HomePage');
#     })();
# </script>
#
# <!-- START: 性能测试监控 -->
# <script>
#     J.ready(function(){
#         var v = 1501241237,
#             src = "//pages.anjukestatic.com/prism/performance.js?v="+v;
#         J.load(src, function(){
#             window.perfConfig = {
#                 pageName : 'Ershou_Web_Home_HomePage',
#                 siteName : 'ershoufang'
#             };
#         })
#     });
# </script>
# <!-- END: 性能测试监控 -->
#
#     <script>
#        $(function(){
#             ajk.exposure = new ajk.Logger.Exposure({
#                 site:'anjuke',
#                 page:'Ershou_Web_Home_HomePage',
#                 pageName:'Ershou_Web_Home_HomePage',
#                 NGuid:'',
#                 NUid:''
#             });
#             ajk.exposure.add($('[data-trace]'));
#         });
#     </script>
# <!-- <script type="text/javascript">
# (function(param){
#        var c = {query:[], args:param||{}};
#        c.query.push(["_setAccount","8"]);//固定参数
#        (window.__zpSMConfig = window.__zpSMConfig||[]).push(c);
#        var zp = document.createElement("script"); zp.type = "text/javascript"; zp.async = true;
#        zp.src = ("https:" == document.location.protocol ? "https:" : "http:") + "//cdn.zampda.net/s.js";
#        var s = document.getElementsByTagName("script")[0]; s.parentNode.insertBefore(zp, s);
# }) (window.__zp_tag_params);
# </script>
#
#  -->
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-66151813-1', 'auto');
#   ga('require', 'displayfeatures');
#   ga('send', 'pageview');
#
# </script>
#
#
# <script>
#
# </script>
#
# <script type="text/javascript">
#     var xxfwConfig = {namespace:'anjuke_c_pc'};
#
#     // 设备指纹js
#     function loadJs() {
#         // 设备指纹js
#         var element = document.createElement("script");
#         var now = new Date()
#         var timestamp=now.getFullYear() +''+now.getMonth() +''+now.getDate()+''+now.getHours();
#         var appKey = 'gk1leqzjj6u65bd2zbal';
#         element.src = "//j1.58cdn.com.cn/git/xxzl/teemo/teemo_init.js?dt="+timestamp+"&appkey="+appKey;
#         document.body.appendChild(element);
#
#         // 反爬虫js
#         // jQuery.getScript("https://pages.anjukestatic.com/usersite/site/js/xxfw.min.js");
#     }
#
#     if (!(navigator.userAgent.match(/miniprogram/i) || window.__wxjs_environment === 'miniprogram')) {
#         if (window.addEventListener) {
#             window.addEventListener("load", loadJs, false);
#         } else if (window.attachEvent) {
#             window.attachEvent("onload", loadJs);
#         } else {
#             window.onload = loadJs;
#         }
#     }
# </script>
#
# <script>
# (function(){
#     var bp = document.createElement('script');
#     var curProtocol = window.location.protocol.split(':')[0];
#     if (curProtocol === 'https'){
#    bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#   }
#   else{
#   bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#   }
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(bp, s);
# })();
# </script>
#
#
# <script type="text/javascript" src="https://pages.anjukestatic.com/usersite/ie/IE886SDK_20200313_01.js"></script>
# <script type="text/javascript">
#     var IE886config = {
#         intervalDay: 1,
#         totalDay: 1000
#     };
#     IE886SDK(IE886config);
# </script>
#    <script type="text/javascript">
#        var userId = '0';
#        var isTest = /test/.test(document.domain)||/dev/.test(document.domain);
#        var appId = 6322339781814;
#        var projectId ='6289197098934';
#        var progectKey ='3kxpt7yb';
#        if(isTest){
#           appId = 6296943323570;
#           projectId = '6289210146098';
#           progectKey = 'w65br84t';
#        }
#        window.WMDA_SDK_CONFIG = ({
#            api_v: 1,
#            sdk_v: 0.1,
#            mode: 'report',
#            appid: appId,
#            key: progectKey,
#            project_id: projectId,
#            // cookie_domain: document.domain,   //58域下不需要该字段
#            cate_id: '',   //按需填写
#            page_extra: [{   //按需填写
#                key: 'pagename',
#                value: 'Ershou_Web_Home_HomePage'
#            },{
#                key: 'city_id',
#                value: '22'
#            }],
#            user_extra: [{   //按需填写
#              key: 'guid',
#              value: '4AF626AF-F7EC-6490-976E-4791E70404D7'
#            }],
#            channel: '',   //按需填写
#            getUserId: function() {
#                return userId;
#            }
#        });
#    </script>
#    <script type="text/javascript" src="//pages.anjukestatic.com/usersite/site/js/wmda_statistic_20190218.js" async="" defer=""></script>
#
#
# <script type="text/javascript" async="" src="//tracklog.58.com/referrer_anjuke_pc.js?_=0.5603521714519757"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.5424180665915932"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.5290744496535735"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.5017620640501945"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.13755076336439354"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.9710087011656814"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.3788782038550731"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.6322547465989714"></script><script type="text/javascript" async="" src="//tracklog.58.com/referrer4.js?_=0.40664573443942875"></script><script src="//j1.58cdn.com.cn/git/xxzl/teemo/teemo_init.js?dt=20215310&amp;appkey=gk1leqzjj6u65bd2zbal"></script></body></html>
# Time Out

# %%
import requests
from bs4 import BeautifulSoup
import random
import time
import csv


headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.142 Safari/537.36'
}

def parse_pages(url, num):
    response = requests.get(url=url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    print(soup)
    result_list = soup.find_all('li', class_='list-item')
    print(len(result_list))
    for result in result_list:
        # 标题
        title = result.find('a', class_='houseListTitle').text.strip()
        # print(title)
        # 户型
        layout = result.select('.details-item > span')[0].text
        # print(layout)
        # 面积
        cover = result.select('.details-item > span')[1].text
        # print(cover)
        # 楼层
        floor = result.select('.details-item > span')[2].text
        # print(floor)
        # 建造年份
        year = result.select('.details-item > span')[3].text
        # print(year)
        # 单价
        unit_price = result.find('span', class_='unit-price').text.strip()
        # print(unit_price)
        # 总价
        total_price = result.find('span', class_='price-det').text.strip()
        # print(total_price)
        # 关键字
        keyword = result.find('div', class_='tags-bottom').text.strip()
        # print(keyword)
        # 地址
        address = result.find('span', class_='comm-address').text.replace(' ', '').replace('\n', '')
        # print(address)
        # 详情页url
        details_url = result.find('a', class_='houseListTitle')['href']
        # print(details_url)
        results = [title, layout, cover, floor, year, unit_price, total_price, keyword, address, details_url]
        with open('anjuke.csv', 'a', newline='', encoding='utf-8-sig') as f:
            w = csv.writer(f)
            w.writerow(results)

    # 判断是否还有下一页
    next_url = soup.find_all('a', class_='aNxt')
    if len(next_url) != 0:
        num += 1
        print('第' + str(num) + '页数据爬取完毕！')
        # 3-60秒之间随机暂停
        time.sleep(random.randint(3, 60))
        parse_pages(next_url[0].attrs['href'], num)
    else:
        print('所有数据爬取完毕！')


if __name__ == '__main__':
    with open('anjuke.csv', 'a', newline='', encoding='utf-8-sig') as fp:
        writer = csv.writer(fp)
        writer.writerow(['标题', '户型', '面积', '楼层', '建造年份', '单价', '总价', '关键字', '地址', '详情页地址'])
    start_num = 0
    start_url = 'https://wh.fang.anjuke.com/aifang/web/loupan/ajax/resource/?t=1622687555419&limit=2&soj=zybh-pc-31&city_id=22&subregion_id=&region_id=&resource_id=1310310'
    parse_pages(start_url, start_num)
# Out:
# 0
# 所有数据爬取完毕！
