# %%
import pandas as pd
data_1 = pd.read_csv('recommend_address_perfer_and_yw_0525.csv')
data_2 = pd.read_csv('recommend_address_perfer_and_yw_0525_r_17.csv')

# %%
data_1.head(10)
# Out:
#     latitude   longitude  kd_ratio  5G_ratio  city_code city_name county_code  \
# 0  27.539721  104.480951    0.3016    0.6984        870        昭通        C0LJ
# 1  24.630712  102.683126    0.5814    0.4186        871        昆明        A0AD
# 2  25.127941  102.973153    0.5973    0.4027        871        昆明        A0AM
# 3  25.353452  103.060925    0.5882    0.4118        871        昆明        A0AH
# 4  24.871612  102.513318    0.5459    0.4541        871        昆明        A0AG
# 5  24.905374  102.650140    0.5764    0.4236        871        昆明        A0AN
# 6  24.992504  102.882566    0.5085    0.4915        871        昆明        A0AE
# 7  25.292332  102.948805    0.6667    0.3333        871        昆明        A0AH
# 8  24.820167  102.632790    0.6932    0.3068        871        昆明        A0AN
# 9  24.710951  102.556620    0.4925    0.5075        871        昆明        A0AD
#
#   county_name     grid_code grid_name
# 0         镇雄县  530627209000       花山乡
# ...

# %%
data_2.grid_name.value_counts()
# Out:
# 嘎洒镇     26
# 板桥镇     21
# 平远镇     20
# 鸡街镇     18
# 营盘镇     17
#         ..
# 因远镇      1
# 湾塘乡      1
# 瑶区乡      1
# 广文网格     1
# 广卫网格     1
# Name: grid_name, Length: 1205, dtype: int64
